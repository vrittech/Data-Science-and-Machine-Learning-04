# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ### From Database

# %%
conn = sqlite3.connect('sql-murder-mystery.db')

# %%
from_db = pd.read_sql('SELECT * FROM Person',conn)

# %%
from_db
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %% [markdown]
# ### From API

# %%
import requests

# %%
api_data = requests.get(
    "https://fakerapi.it/api/v1/persons?_quantity=10", 
    # headers = {
    #     "API-key" : "saedgarhgrghwrgawgrag"
    # }
)

# %%
response_data = api_data.json()['data']

# %%
pd.DataFrame(response_data).head()
# Out:
#    id firstname     lastname                         email           phone  \
# 0   1      Name        Frami     dusty.hermiston@yahoo.com  +6911657996503
# 1   2   Araceli  Stoltenberg  kertzmann.golda@leuschke.com  +5830298850233
# 2   3      Eden       Hamill         mcglynn.dee@yahoo.com  +6884392214322
# 3   4   Garland     Emmerich     abshire.laverna@yahoo.com  +8867582411057
# 4   5    Mathew     Tremblay  remington.blick@roberts.info  +2745829307438
#
#      birthday  gender                                            address  \
# 0  2018-06-05  female  {'id': 0, 'street': '211 Daugherty Mission', '...
# 1  1996-06-19  female  {'id': 0, 'street': '36283 Stephon Ridge Suite...
# 2  1975-03-12  female  {'id': 0, 'street': '823 Maci Loop', 'streetNa...
# 3  1955-03-22    male  {'id': 0, 'street': '572 Kovacek Turnpike', 's...
# 4  1999-04-12    male  {'id': 0, 'street': '182 Reinger Rest', 'stree...
#
#                 website                               image
# ...

# %% [markdown]
# ### Revision
